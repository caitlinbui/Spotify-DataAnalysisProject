# %%
import matplotlib.pyplot as plt 
import pandas as pd
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\cmeka\miniconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\cmeka\miniconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cmeka\miniconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cmeka\miniconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\cmeka\miniconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\cmeka\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
og = pd.read_csv('spotify_songs.csv')

#We made a column for just the year
og["year"] = pd.to_datetime(og["track_album_release_date"], format="mixed", errors="coerce").dt.year

#Converting milliseconds to mins
og["mins"] = og["duration_ms"] / 60000 
og.head()
og.shape
# Out:
# (32833, 25)

# %% [markdown]
# There are 23 features, and 32,833 observations (songs). Features: track id, track name, track artist, track popularity (0-100 scale), album id, album name, album release date, playlist name, playlist id, playlist genre, key (overall pitch), loudness (-60 to 0 db scale), mode (major - 1 or minor - 0), speechiness (detects presence of spoken words) , acousticness (0.0 to 1.0 scale of whether the track is acoustic), instrumentalness (0.0 to 1.0 scale, Predicts whether a track has no vocals), liveness (presence of an audience during recording, > 0.8 means inc prob that track was performed live), valence (0.0 to 10.0 scale, decribes musical positiveness of a track) , tempo (BPM), duration (ms).

# %% [markdown]
# To start, we will need to drop features we aren't testing or do not need for our goal.

# %%
df = og[['track_name', 'era' ,'track_artist', 'year','track_popularity','valence_scale']]
 # The first five songs of our derived dataset. 

bins = [0, 1999, 2010, 2020] 
labels = ["1900s", "2000–2010", "2011–2020"]
og["era"] = pd.cut(df["year"], bins=bins, labels=labels)
df.head()

og["valence"] = pd.to_numeric(og["valence"], errors="coerce")
bins = [0.0,0.3,0.5,0.7, 1.0] 
labels = ["very low", "low", "high", "very high"]
og["valence_scale"] = pd.cut(og["valence"], bins=bins, labels=labels, include_lowest=True)
df.head(15)
# Out:
#                                            track_name        era  \
# 0   I Don't Care (with Justin Bieber) - Loud Luxur...  2011–2020
# 1                     Memories - Dillon Francis Remix  2011–2020
# 2                     All the Time - Don Diablo Remix  2011–2020
# 3                   Call You Mine - Keanu Silva Remix  2011–2020
# 4             Someone You Loved - Future Humans Remix  2011–2020
# 5   Beautiful People (feat. Khalid) - Jack Wins Remix  2011–2020
# 6                     Never Really Over - R3HAB Remix  2011–2020
# 7            Post Malone (feat. RANI) - GATTÜSO Remix  2011–2020
# 8              Tough Love - Tiësto Remix / Radio Edit  2011–2020
# 9                 If I Can't Have You - Gryffin Remix  2011–2020
# 10  Cross Me (feat. Chance the Rapper & PnB Rock) ...  2011–2020
# 11                              Hate Me - R3HAB Remix  2011–2020
# 12                                         Body On My  2011–2020
# 13     SOS - Laidback Luke Tribute Remix / Radio Edit  2011–2020
# 14  Summer Days (feat. Macklemore & Patrick Stump ...  2011–2020
#
#         track_artist  year  track_popularity valence_scale
# 0         Ed Sheeran  2019                66          high
# 1           Maroon 5  2019                67          high
# 2       Zara Larsson  2019                70          high
# 3   The Chainsmokers  2019                60      very low
# 4      Lewis Capaldi  2019                69     very high
# 5         Ed Sheeran  2019                67          high
# 6         Katy Perry  2019                62      very low
# 7          Sam Feldt  2019                69           low
# 8             Avicii  2019                68           low
# 9       Shawn Mendes  2019                67          high
# 10        Ed Sheeran  2019                58     very high
# 11    Ellie Goulding  2019                67           low
# 12       Loud Luxury  2019                67          high
# 13            Avicii  2019                68          high
# 14     Martin Garrix  2019                63      very low

# %% [markdown]
# We can also display info in ascending order

# %% [markdown]
# We want to group songs by year:

# %%
songs2000s = df[(df["year"] >= 2000) & (df["year"] <= 2010)]
songs2000s

songs2010s = df[(df["year"] > 2010) & (df["year"] <= 2020)]
songs2010s

songs1900s = df[df["year"] < 2000]
songs1900s
# Out:
#                             track_name    era    track_artist  year  \
# 749      We like to Party! (Six Flags)  1900s       Vengaboys  1998
# 750        Coco Jamboo - Radio Version  1900s   Mr. President  1996
# 751                   Blue (Da Ba Dee)  1900s       Eiffel 65  1999
# 753                       What Is Love  1900s        Haddaway  1993
# 754    Scatman (ski-ba-bop-ba-dop-bop)  1900s    Scatman John  1995
# ...                                ...    ...             ...   ...
# 31690        I Feel Love - 12" Version  1900s    Donna Summer  1979
# 31694                      Dance Freak  1900s  Chain Reaction  1980
# 31703                       Hold Tight  1900s     Gino Soccio  1994
# 31704                           Janice  1900s    Skip Mahoney  1993
# 31708                   Bailar la Soca  1900s   Cuba Trinidad  1991
#
#        track_popularity valence_scale
# 749                  51     very high
# 750                  18     very high
# 751                  16     very high
# 753                  70     very high
# 754                  10     very high
# ...                 ...           ...
# 31690                 5     very high
# 31694                29     very high
# 31703                33     very high
# 31704                31     very high
# 31708                15     very high
#
# [4757 rows x 6 columns]

# %%
#PLOTS - plotting popularity vs. 1900s
avg_popularity = df.groupby("year")["track_popularity"].mean()
avg_popularity.plot(kind="bar")

avg_pop = df.groupby("era")["track_popularity"].mean() #the average popularity from songs in each era
avg_pop.plot(kind="bar", figsize=(8,5))
plt.ylabel("Average Popularity")
plt.title("Average Song Popularity by Era")
plt.show()
# Out:
# C:\Users\CmeKa\AppData\Local\Temp\ipykernel_33672\3003601188.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_pop = df.groupby("era")["track_popularity"].mean() #the average popularity from songs in each era

# %%
avgpop = df.groupby("valence_scale")["track_popularity"].mean() #the average popularity from songs in each era
avgpop.plot(kind="bar", figsize=(8,5))
plt.ylabel("Average Popularity")
plt.title("Average Song Popularity by Valence Score")
plt.show()
# Out:
# C:\Users\CmeKa\AppData\Local\Temp\ipykernel_33672\2551510791.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avgpop = df.groupby("valence_scale")["track_popularity"].mean() #the average popularity from songs in each era

# %%
#Most popular tracks:
top_tracks = df.groupby("track_name")["track_popularity"].max().sort_values(ascending = False)
top_tracks
# Out:
# track_name
# Dance Monkey                      100
# ROXANNE                            99
# Circles                            98
# Blinding Lights                    98
# Memories                           98
#                                  ...
# Upgraded                            0
# Ipanema - Original Mix              0
# Invitation (feat. Yade Lauren)      0
# Invincible - Radio Edit             0
# I'm Gonna Be Alright                0
# Name: track_popularity, Length: 23449, dtype: int64
